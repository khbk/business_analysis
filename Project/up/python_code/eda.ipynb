# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
up = pd.read_csv("./data/up.csv")

# %%
up.head()
# Out:
#           Unnamed: 0 (Revenue Report)      이번 달로 가기        총매출     PACK  \
# 0           2020년 7월        $1,956.56  7/1/2020 Wed  $1,524.00  $580.84
# 1                NaN              NaN  7/2/2020 Thu  $1,580.41  $543.89
# 2      Total Revenue       $54,783.59  7/3/2020 Fri  $2,205.65  $803.29
# 3           Reported       $47,375.02  7/4/2020 Sat        NaN      NaN
# 4  Revenue from Card       $29,503.27  7/5/2020 Sun        NaN      NaN
#
#   CARTON     GRCY GRCY NT KRATOM     MISC  ... LOTTO P/O SCRATCH.1  \
# 0  $0.00  $224.90     NaN    NaN   $20.32  ...       NaN       NaN
# 1  $0.00  $326.50   $0.00    NaN   $49.21  ...       NaN       NaN
# 2  $0.00  $266.26   $0.00    NaN  $150.82  ...       NaN       NaN
# 3    NaN      NaN     NaN    NaN      NaN  ...       NaN       NaN
# 4    NaN      NaN     NaN    NaN      NaN  ...       NaN       NaN
#
#   SCRATCH P/O      $0.00 TOTALnontax Unnamed: 46    이번 달로 가기.1 Grcy NT  \
# 0         NaN  $1,524.00         NaN         NaN  7/1/2020 Wed     NaN
# 1         NaN  $1,580.41         NaN         NaN  7/2/2020 Thu   $0.00
# 2         NaN  $2,205.65         NaN         NaN  7/3/2020 Fri   $0.00
# 3         NaN      $0.00         NaN         NaN  7/4/2020 Sat     NaN
# 4         NaN      $0.00         NaN         NaN  7/5/2020 Sun     NaN
#
#         TOTAL Unnamed: 50
# 0  -$1,524.00     $861.87
# 1  -$1,580.41     $669.42
# 2  -$2,205.65     $909.67
# 3       $0.00       $0.00
# 4       $0.00       $0.00
#
# [5 rows x 51 columns]

# %%
# Omit some columns that are not used.
up.drop(columns=['Unnamed: 0', '(Revenue Report)','잡화 비율', '카드/총매출', 
                 'Unnamed: 25', 'Unnamed: 26', '주', '주별 평균 매출','PACK.1', 
                 'CARTON.1', 'GRCY.1', 'GRCY NT.1', 'KRATOM.1', 'MISC.1',
                 'VAPE.1', 'APPAREL.1', 'TOBACCO.1', 'BEER', 'CIGAR.1', 'LOTTO.1',
                 'LOTTO P/O', 'SCRATCH.1', 'SCRATCH P/O', '$0.00', 'TOTALnontax',
                 'Unnamed: 46', '이번 달로 가기.1', 'Grcy NT', 'TOTAL', 'Unnamed: 50'], 
        inplace=True)

# %%
# Change the column names.
up.rename(columns={"이번 달로 가기": "date", "총매출": "total", 
                   "메인포스": "main", "카드": "card"}, inplace=True);

# %%
# Change uppercase column names to lowercase and put _ for spaces
up.columns = [col.replace(' ', '_').lower() for col in up.columns]
up.columns = [col.replace('/', '_') for col in up.columns]
# There was a columns name that had space in the beginning
up.rename(columns={"_beer": "beer"}, inplace=True);

# %%
# Set 'date' column as index
up = up.set_index('date')

# %%
pd.set_option('display.max_columns', None)
up.head()
# Out:
#                   total     pack carton     grcy grcy_nt kratom     misc vape  \
# date
# 7/1/2020 Wed  $1,524.00  $580.84  $0.00  $224.90     NaN    NaN   $20.32  NaN
# 7/2/2020 Thu  $1,580.41  $543.89  $0.00  $326.50   $0.00    NaN   $49.21  NaN
# 7/3/2020 Fri  $2,205.65  $803.29  $0.00  $266.26   $0.00    NaN  $150.82  NaN
# 7/4/2020 Sat        NaN      NaN    NaN      NaN     NaN    NaN      NaN  NaN
# 7/5/2020 Sun        NaN      NaN    NaN      NaN     NaN    NaN      NaN  NaN
#
#              apparel  tobacco     beer cigar cigar_accessory cbd_d8 lotto  \
# date
# 7/1/2020 Wed     NaN  $122.44  $439.68   NaN             NaN    NaN   NaN
# 7/2/2020 Thu     NaN   $95.56  $424.22   NaN             NaN    NaN   NaN
# 7/3/2020 Fri     NaN  $112.75  $662.65   NaN             NaN    NaN   NaN
# 7/4/2020 Sat     NaN      NaN      NaN   NaN             NaN    NaN   NaN
# 7/5/2020 Sun     NaN      NaN      NaN   NaN             NaN    NaN   NaN
#
#               p_o scratch scp_o        main       card
# date
# 7/1/2020 Wed  NaN     NaN   NaN  -$1,524.00    $662.13
# 7/2/2020 Thu  NaN     NaN   NaN  -$1,580.41    $910.99
# 7/3/2020 Fri  NaN     NaN   NaN  -$2,205.65  $1,295.98
# 7/4/2020 Sat  NaN     NaN   NaN         NaN        NaN
# 7/5/2020 Sun  NaN     NaN   NaN         NaN        NaN

# %%
# Delete rows that contain null values for all
up.dropna(thresh=10, inplace=True)

# %%
pd.set_option('display.max_columns', None)
up.head(20)
# Out:
#                    total     pack  carton     grcy grcy_nt kratom     misc  \
# date
# 7/2/2020 Thu   $1,580.41  $543.89   $0.00  $326.50   $0.00    NaN   $49.21
# 7/3/2020 Fri   $2,205.65  $803.29   $0.00  $266.26   $0.00    NaN  $150.82
# 7/7/2020 Tue   $1,059.06  $450.29   $0.00  $102.78   $0.00    NaN   $49.06
# 7/8/2020 Wed   $1,578.40  $581.69   $0.00  $167.32  $14.62    NaN   $79.47
# 7/9/2020 Thu   $1,690.63  $583.25  $82.70  $199.81   $5.87    NaN  $159.47
# 7/10/2020 Fri  $2,112.67  $682.47   $0.00  $192.46  $28.28    NaN  $116.80
# 7/11/2020 Sat  $1,623.80  $578.79   $0.00  $115.46  $50.08    NaN  $201.82
# 7/12/2020 Sun  $1,608.18  $547.03   $0.00  $123.31  $39.76    NaN  $171.87
# 7/13/2020 Mon  $1,963.52  $748.12   $0.00  $157.58  $59.97    NaN  $153.59
# 7/14/2020 Tue  $1,802.30  $554.93   $0.00  $164.46  $32.85    NaN  $283.31
# 7/15/2020 Wed  $1,946.40  $550.73   $0.00  $191.18  $70.36    NaN  $282.97
# 7/16/2020 Thu  $2,240.16  $652.38   $0.00  $168.72  $32.33    NaN  $204.09
# 7/17/2020 Fri  $2,384.22  $657.40   $0.00  $140.58  $42.04    NaN  $457.31
# 7/18/2020 Sat  $2,350.18  $654.86   $0.00   $50.75  $60.86    NaN  $264.84
# 7/19/2020 Sun  $1,842.31  $537.77   $0.00  $163.25  $23.32    NaN  $230.40
# 7/20/2020 Mon  $2,170.59  $740.00   $0.00  $210.87  $39.02    NaN  $330.48
# 7/21/2020 Tue  $1,905.09  $369.63  $82.70  $195.66  $32.87    NaN  $209.26
# 7/22/2020 Wed  $1,857.88  $617.87   $0.00  $173.63  $23.09    NaN  $169.13
# 7/23/2020 Thu  $2,031.73  $528.81  $87.10  $106.10  $97.79    NaN  $261.08
# 7/24/2020 Fri  $2,366.84  $552.64   $0.00  $154.88  $61.80    NaN  $205.38
#
#                   vape apparel  tobacco     beer cigar cigar_accessory cbd_d8  \
# date
# 7/2/2020 Thu       NaN     NaN   $95.56  $424.22   NaN             NaN    NaN
# 7/3/2020 Fri       NaN     NaN  $112.75  $662.65   NaN             NaN    NaN
# 7/7/2020 Tue       NaN     NaN   $61.23  $301.79   NaN             NaN    NaN
# 7/8/2020 Wed    $55.97     NaN   $64.66  $472.38   NaN             NaN    NaN
# 7/9/2020 Thu    $96.94     NaN   $75.61  $333.66   NaN             NaN    NaN
# 7/10/2020 Fri   $47.97     NaN   $70.92  $784.08   NaN             NaN    NaN
# 7/11/2020 Sat   $92.96     NaN   $35.02  $406.49   NaN             NaN    NaN
# 7/12/2020 Sun  $115.13     NaN   $96.98  $371.42   NaN             NaN    NaN
# 7/13/2020 Mon   $88.95     NaN  $102.55  $480.49   NaN             NaN    NaN
# 7/14/2020 Tue   $74.30     NaN   $48.47  $517.28   NaN             NaN    NaN
# 7/15/2020 Wed   $82.95     NaN   $74.93  $409.63   NaN             NaN    NaN
# 7/16/2020 Thu  $376.94     NaN  $122.53  $482.98   NaN             NaN    NaN
# 7/17/2020 Fri  $202.83     NaN  $114.70  $556.22   NaN             NaN    NaN
# 7/18/2020 Sat  $146.90     NaN  $136.92  $762.64   NaN             NaN    NaN
# 7/19/2020 Sun  $157.91     NaN   $85.56  $477.19   NaN             NaN    NaN
# 7/20/2020 Mon  $140.89     NaN   $96.11  $419.24   NaN             NaN    NaN
# 7/21/2020 Tue  $156.88     NaN  $107.65  $580.04   NaN             NaN    NaN
# 7/22/2020 Wed  $287.81     NaN  $115.82  $303.19   NaN             NaN    NaN
# 7/23/2020 Thu  $150.91     NaN  $109.18  $535.61   NaN             NaN    NaN
# 7/24/2020 Fri  $346.78     NaN  $111.52  $723.22   NaN             NaN    NaN
#
#               lotto  p_o scratch scp_o        main       card
# date
# 7/2/2020 Thu    NaN  NaN     NaN   NaN  -$1,580.41    $910.99
# 7/3/2020 Fri    NaN  NaN     NaN   NaN  -$2,205.65  $1,295.98
# 7/7/2020 Tue    NaN  NaN     NaN   NaN  -$1,059.06    $418.33
# 7/8/2020 Wed    NaN  NaN     NaN   NaN  -$1,578.40    $797.50
# 7/9/2020 Thu    NaN  NaN     NaN   NaN  -$1,690.63    $827.64
# 7/10/2020 Fri   NaN  NaN     NaN   NaN  -$2,112.67  $1,168.12
# 7/11/2020 Sat   NaN  NaN     NaN   NaN  -$1,623.80    $808.51
# 7/12/2020 Sun   NaN  NaN     NaN   NaN  -$1,456.06    $749.57
# 7/13/2020 Mon   NaN  NaN     NaN   NaN  -$1,595.40    $960.32
# 7/14/2020 Tue   NaN  NaN     NaN   NaN  -$1,126.79    $760.12
# 7/15/2020 Wed   NaN  NaN     NaN   NaN  -$1,530.28    $912.50
# 7/16/2020 Thu   NaN  NaN     NaN   NaN  -$1,959.85  $1,287.15
# 7/17/2020 Fri   NaN  NaN     NaN   NaN  -$1,906.47  $1,309.37
# 7/18/2020 Sat   NaN  NaN     NaN   NaN  -$2,118.21  $1,497.40
# 7/19/2020 Sun   NaN  NaN     NaN   NaN  -$1,398.76    $936.91
# 7/20/2020 Mon   NaN  NaN     NaN   NaN  -$1,533.01    $877.83
# 7/21/2020 Tue   NaN  NaN     NaN   NaN  -$1,539.29  $1,142.32
# 7/22/2020 Wed   NaN  NaN     NaN   NaN  -$1,643.66  $1,079.46
# 7/23/2020 Thu   NaN  NaN     NaN   NaN  -$1,698.84  $1,145.29
# 7/24/2020 Fri   NaN  NaN     NaN   NaN  -$2,058.17  $1,569.53

# %%
up.head()
# Out:
#                   total     pack  carton     grcy grcy_nt kratom     misc  \
# date
# 7/2/2020 Thu  $1,580.41  $543.89   $0.00  $326.50   $0.00    NaN   $49.21
# 7/3/2020 Fri  $2,205.65  $803.29   $0.00  $266.26   $0.00    NaN  $150.82
# 7/7/2020 Tue  $1,059.06  $450.29   $0.00  $102.78   $0.00    NaN   $49.06
# 7/8/2020 Wed  $1,578.40  $581.69   $0.00  $167.32  $14.62    NaN   $79.47
# 7/9/2020 Thu  $1,690.63  $583.25  $82.70  $199.81   $5.87    NaN  $159.47
#
#                 vape apparel  tobacco     beer cigar cigar_accessory cbd_d8  \
# date
# 7/2/2020 Thu     NaN     NaN   $95.56  $424.22   NaN             NaN    NaN
# 7/3/2020 Fri     NaN     NaN  $112.75  $662.65   NaN             NaN    NaN
# 7/7/2020 Tue     NaN     NaN   $61.23  $301.79   NaN             NaN    NaN
# 7/8/2020 Wed  $55.97     NaN   $64.66  $472.38   NaN             NaN    NaN
# 7/9/2020 Thu  $96.94     NaN   $75.61  $333.66   NaN             NaN    NaN
#
#              lotto  p_o scratch scp_o        main       card
# date
# 7/2/2020 Thu   NaN  NaN     NaN   NaN  -$1,580.41    $910.99
# 7/3/2020 Fri   NaN  NaN     NaN   NaN  -$2,205.65  $1,295.98
# 7/7/2020 Tue   NaN  NaN     NaN   NaN  -$1,059.06    $418.33
# 7/8/2020 Wed   NaN  NaN     NaN   NaN  -$1,578.40    $797.50
# 7/9/2020 Thu   NaN  NaN     NaN   NaN  -$1,690.63    $827.64

# %%
# Found a major flaw to the data frame. All the values have '$' in front 
# of the digits that makes the data types all objects.
up.dtypes
# Out:
# total              object
# pack               object
# carton             object
# grcy               object
# grcy_nt            object
# kratom             object
# misc               object
# vape               object
# apparel            object
# tobacco            object
# beer               object
# cigar              object
# cigar_accessory    object
# cbd_d8             object
# lotto              object
# p_o                object
# scratch            object
# scp_o              object
# main               object
# card               object
# dtype: object

# %%
# We would need to take the '$' out and make them into floats.
for i in up.columns:
    up[i] = up[i].str.replace('$','')
# Out:
# C:\Users\kyoun\AppData\Local\Temp/ipykernel_5404/1561699701.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   up[i] = up[i].str.replace('$','')

# %%
up.head()
# Out:
#                  total    pack carton    grcy grcy_nt kratom    misc   vape  \
# date
# 7/2/2020 Thu  1,580.41  543.89   0.00  326.50    0.00    NaN   49.21    NaN
# 7/3/2020 Fri  2,205.65  803.29   0.00  266.26    0.00    NaN  150.82    NaN
# 7/7/2020 Tue  1,059.06  450.29   0.00  102.78    0.00    NaN   49.06    NaN
# 7/8/2020 Wed  1,578.40  581.69   0.00  167.32   14.62    NaN   79.47  55.97
# 7/9/2020 Thu  1,690.63  583.25  82.70  199.81    5.87    NaN  159.47  96.94
#
#              apparel tobacco    beer cigar cigar_accessory cbd_d8 lotto  p_o  \
# date
# 7/2/2020 Thu     NaN   95.56  424.22   NaN             NaN    NaN   NaN  NaN
# 7/3/2020 Fri     NaN  112.75  662.65   NaN             NaN    NaN   NaN  NaN
# 7/7/2020 Tue     NaN   61.23  301.79   NaN             NaN    NaN   NaN  NaN
# 7/8/2020 Wed     NaN   64.66  472.38   NaN             NaN    NaN   NaN  NaN
# 7/9/2020 Thu     NaN   75.61  333.66   NaN             NaN    NaN   NaN  NaN
#
#              scratch scp_o       main      card
# date
# 7/2/2020 Thu     NaN   NaN  -1,580.41    910.99
# 7/3/2020 Fri     NaN   NaN  -2,205.65  1,295.98
# 7/7/2020 Tue     NaN   NaN  -1,059.06    418.33
# 7/8/2020 Wed     NaN   NaN  -1,578.40    797.50
# 7/9/2020 Thu     NaN   NaN  -1,690.63    827.64

# %%
up = up.fillna(0)

# %%
for i in up.columns:
    up[i] = up[i].str.replace(',','')

# %%
for i in up.columns:
    up[[i]] = up[[i]].astype(float)

# %%
up = up.fillna(0)

# %%
up['misc_total'] = up['misc'] + up['kratom'] + up['apparel'] + up['cigar_accessory'] + up['cbd_d8']

# %%
up.drop(columns=['misc', 'kratom', 'apparel', 'cigar_accessory', 'cbd_d8'])
# Out:
#                  total    pack  carton    grcy  grcy_nt     vape  tobacco  \
# date
# 7/2/2020 Thu   1580.41  543.89    0.00  326.50     0.00     0.00    95.56
# 7/3/2020 Fri   2205.65  803.29    0.00  266.26     0.00     0.00   112.75
# 7/7/2020 Tue   1059.06  450.29    0.00  102.78     0.00     0.00    61.23
# 7/8/2020 Wed   1578.40  581.69    0.00  167.32    14.62    55.97    64.66
# 7/9/2020 Thu   1690.63  583.25   82.70  199.81     5.87    96.94    75.61
# ...                ...     ...     ...     ...      ...      ...      ...
# 5/13/2022 Fri  7904.24  833.19  197.20  138.73    79.00  2296.47   366.86
# 5/14/2022 Sat  7405.19  731.88    0.00  146.26   115.03  1851.58   401.62
# 5/15/2022 Sun  4791.93  475.36  280.50  148.64   138.21  1138.10   372.31
# 5/16/2022 Mon  5227.22  723.60  116.09  134.52    68.14  1437.38   339.03
# 9/3/2020 Thu   3000.30  707.92    0.00  215.04    64.62   475.95   172.58
#
#                  beer    cigar  lotto   p_o  scratch  scp_o     main     card  \
# date
# 7/2/2020 Thu   424.22     0.00    0.0   0.0      0.0    0.0 -1580.41   910.99
# 7/3/2020 Fri   662.65     0.00    0.0   0.0      0.0    0.0 -2205.65  1295.98
# 7/7/2020 Tue   301.79     0.00    0.0   0.0      0.0    0.0 -1059.06   418.33
# 7/8/2020 Wed   472.38     0.00    0.0   0.0      0.0    0.0 -1578.40   797.50
# 7/9/2020 Thu   333.66     0.00    0.0   0.0      0.0    0.0 -1690.63   827.64
# ...               ...      ...    ...   ...      ...    ...      ...      ...
# 5/13/2022 Fri  980.58   944.18   89.0 -20.0     92.0  -34.0 -6623.36  5232.93
# 5/14/2022 Sat  756.82  1153.91  131.0  -5.0    136.0  -40.0 -6268.43  4999.85
# 5/15/2022 Sun  629.18   139.89   38.0   0.0    129.0  -58.0 -4044.67  3057.25
# 5/16/2022 Mon  562.45   260.61  134.0  -5.0     94.0  -16.0  4025.83  3175.00
# 9/3/2020 Thu   607.52    67.22    0.0   0.0      0.0    0.0 -2240.44  1669.09
#
#                misc_total
# date
# 7/2/2020 Thu        49.21
# 7/3/2020 Fri       150.82
# 7/7/2020 Tue        49.06
# 7/8/2020 Wed        79.47
# 7/9/2020 Thu       159.47
# ...                   ...
# 5/13/2022 Fri     1226.47
# 5/14/2022 Sat     1380.93
# 5/15/2022 Sun     1006.46
# 5/16/2022 Mon     1031.87
# 9/3/2020 Thu       422.38
#
# [681 rows x 16 columns]

# %%
up.drop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5404/3059109582.py in <module>
# ----> 1 up.drop('681')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4212                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4213                 if errors == "raise" and labels_missing:
# -> 4214                     raise KeyError(f"{labels} not found in axis")
#    4215
#    4216             slicer = [slice(None)] * self.ndim
#
# KeyError: "['681'] not found in axis"
