# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
up_time = pd.read_csv('../data/up_df.csv')
up_time
# Out:
#            date    total    pack  carton    grcy  grcy_nt  misc_total  \
# 0    2020-07-01  1524.00  580.84    0.00  224.90     0.00       20.32
# 1    2020-07-02  1580.41  543.89    0.00  326.50     0.00       49.21
# 2    2020-07-03  2205.65  803.29    0.00  266.26     0.00      150.82
# 3    2020-07-07  1059.06  450.29    0.00  102.78     0.00       49.06
# 4    2020-07-08  1578.40  581.69    0.00  167.32    14.62       79.47
# ..          ...      ...     ...     ...     ...      ...         ...
# 676  2022-05-12  6695.15  737.72   68.70  141.68    79.94     1258.25
# 677  2022-05-13  7904.24  833.19  197.20  138.73    79.00     1226.47
# 678  2022-05-14  7405.19  731.88    0.00  146.26   115.03     1380.93
# 679  2022-05-15  4791.93  475.36  280.50  148.64   138.21     1006.46
# 680  2022-05-16  5227.22  723.60  116.09  134.52    68.14     1031.87
#
#         vape  tobacco    beer    cigar  lotto   p_o  scratch  scp_o     main  \
# ...

# %%
up_time['date'] = pd.to_datetime(up_time['date'])

# %%
up_time.set_index('date', inplace = True)

# %%
up_time.resample('M').mean()
# Out:
#                   total        pack      carton        grcy    grcy_nt  \
# date
# 2020-07-31  1956.556786  586.214643    9.017857  172.265714  40.280714
# 2020-08-31  2287.933548  557.845484   10.638387  110.739032  78.620968
# 2020-09-30  2877.151667  606.044333   27.143333  103.628000  70.171000
# 2020-10-31  2983.617742  574.779355   21.638710   81.422581  63.537742
# 2020-11-30  3112.356000  562.611000   32.783667   81.000000  58.130333
# 2020-12-31  3675.548065  587.556129   38.506452   82.418387  51.317742
# 2021-01-31  3986.183548  612.958710   38.158065   93.507742  50.389677
# 2021-02-28  4094.423214  671.320000   67.513929   94.918571  49.768214
# 2021-03-31  4660.904839  618.581935   65.416129  118.356129  62.240323
# 2021-04-30  4963.202333  666.753333   70.326667  123.787667  65.651000
# 2021-05-31  4976.609677  676.816774   85.902581  117.037419  60.770000
# 2021-06-30  5171.515000  710.831333   90.066667  134.183667  65.013333
# ...

# %%
plt.figure(figsize=(12,8))
plt.title('Monthly Total', fontsize=16)
plt.ylabel('USD', fontsize=16)
plt.xlabel('Time', fontsize=16)
plt.plot(up_time['total'])
plt.plot(up_time['total'].rolling(30).mean());

# %%
fig, axes = plt.subplots(nrows=9, figsize=(15,12))
axes[0].plot(up_time['pack'])
axes[1].plot(up_time['carton'])
axes[2].plot(up_time['grcy'])
axes[3].plot(up_time['grcy_nt'])
axes[4].plot(up_time['vape'])
axes[5].plot(up_time['tobacco'])
axes[6].plot(up_time['beer'])
axes[7].plot(up_time['cigar'])
axes[8].plot(up_time['misc_total']);

# %%
up_time.pct_change()
# Out:
#                total      pack    carton      grcy   grcy_nt  misc_total  \
# date
# 2020-07-01       NaN       NaN       NaN       NaN       NaN         NaN
# 2020-07-02  0.037014 -0.063615       NaN  0.451756       NaN    1.421752
# 2020-07-03  0.395619  0.476935       NaN -0.184502       NaN    2.064824
# 2020-07-07 -0.519842 -0.439443       NaN -0.613986       NaN   -0.674712
# 2020-07-08  0.490378  0.291812       NaN  0.627943       inf    0.619853
# ...              ...       ...       ...       ...       ...         ...
# 2022-05-12  0.002661 -0.129955 -0.515651 -0.080895  0.116480   -0.131643
# 2022-05-13  0.180592  0.129412  1.870451 -0.020822 -0.011759   -0.025257
# 2022-05-14 -0.063137 -0.121593 -1.000000  0.054278  0.456076    0.125939
# 2022-05-15 -0.352896 -0.350495       inf  0.016272  0.201513   -0.271172
# 2022-05-16  0.090838  0.522215 -0.586132 -0.094995 -0.506982    0.025247
#
#                 vape   tobacco      beer     cigar     lotto   p_o   scratch  \
# ...

# %%
up_time.diff()
# Out:
#               total    pack  carton    grcy  grcy_nt  misc_total    vape  \
# date
# 2020-07-01      NaN     NaN     NaN     NaN      NaN         NaN     NaN
# 2020-07-02    56.41  -36.95    0.00  101.60     0.00       28.89    0.00
# 2020-07-03   625.24  259.40    0.00  -60.24     0.00      101.61    0.00
# 2020-07-07 -1146.59 -353.00    0.00 -163.48     0.00     -101.76    0.00
# 2020-07-08   519.34  131.40    0.00   64.54    14.62       30.41   55.97
# ...             ...     ...     ...     ...      ...         ...     ...
# 2022-05-12    17.77 -110.19  -73.14  -12.47     8.34     -190.75  669.01
# 2022-05-13  1209.09   95.47  128.50   -2.95    -0.94      -31.78 -210.95
# 2022-05-14  -499.05 -101.31 -197.20    7.53    36.03      154.46 -444.89
# 2022-05-15 -2613.26 -256.52  280.50    2.38    23.18     -374.47 -713.48
# 2022-05-16   435.29  248.24 -164.41  -14.12   -70.07       25.41  299.28
#
#             tobacco    beer    cigar  lotto   p_o  scratch  scp_o     main  \
# date
# ...
